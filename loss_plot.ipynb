# %%
import joblib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
loss_dict: dict = joblib.load('./loss_65.dict')

# %%
loss_dict
# Out:
# {'train_class_loss_array': array([0.00010237, 0.00031005, 0.00045112, ..., 0.01258543, 0.0126005 ,
#         0.01262005]),
#  'train_domain_loss_array': array([], dtype=float64),
#  'eval_class_loss_array': array([5.61821234e-05, 9.56969728e-05, 1.41601323e-04, ...,
#         8.37802592e-03, 8.41409358e-03, 8.44823339e-03]),
#  'eval_domain_loss_array': array([], dtype=float64),
#  'eval_loss_array': array([0.0106754 , 0.00973002, 0.01069185, 0.00904763, 0.0089107 ,
#         0.00911693, 0.00872221, 0.00885503, 0.00899253, 0.00916883,
#         0.0091603 , 0.00911045, 0.0089737 , 0.00886831, 0.0086365 ,
#         0.0087631 , 0.00879407, 0.00863743, 0.0086492 , 0.00879052,
#         0.00882522, 0.00871692, 0.00849102, 0.00878116, 0.00872725,
#         0.0086178 , 0.00855592, 0.0084899 , 0.00860503, 0.00853958,
#         0.00858251, 0.00847931, 0.00847255, 0.00848024, 0.00867776,
#         0.00867536, 0.00862099, 0.00887119, 0.0085162 , 0.00850568,
# ...

# %%
loss_dict.pop('eval_domain_loss_array', None)
# Out:
# array([], dtype=float64)

# %%
loss_dict
# Out:
# {'train_class_loss_array': array([0.00010237, 0.00031005, 0.00045112, ..., 0.01258543, 0.0126005 ,
#         0.01262005]),
#  'train_domain_loss_array': array([], dtype=float64),
#  'eval_class_loss_array': array([5.61821234e-05, 9.56969728e-05, 1.41601323e-04, ...,
#         8.37802592e-03, 8.41409358e-03, 8.44823339e-03]),
#  'eval_loss_array': array([0.0106754 , 0.00973002, 0.01069185, 0.00904763, 0.0089107 ,
#         0.00911693, 0.00872221, 0.00885503, 0.00899253, 0.00916883,
#         0.0091603 , 0.00911045, 0.0089737 , 0.00886831, 0.0086365 ,
#         0.0087631 , 0.00879407, 0.00863743, 0.0086492 , 0.00879052,
#         0.00882522, 0.00871692, 0.00849102, 0.00878116, 0.00872725,
#         0.0086178 , 0.00855592, 0.0084899 , 0.00860503, 0.00853958,
#         0.00858251, 0.00847931, 0.00847255, 0.00848024, 0.00867776,
#         0.00867536, 0.00862099, 0.00887119, 0.0085162 , 0.00850568,
#         0.0084307 , 0.00861841, 0.00848775, 0.00868842, 0.00845944,
# ...
