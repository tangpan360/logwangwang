# %%
import joblib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
loss_dict: dict = joblib.load('./loss_path/loss.dict')

# %%
loss_dict
# Out:
# {'train_class_loss_array': array([0.05713638, 0.03318936, 0.01707259, ...,        nan,        nan,
#                nan]),
#  'train_domain_loss_array': array([0.72920826, 0.55505   , 0.34935371, ...,        nan,        nan,
#                nan]),
#  'eval_class_loss_array': array([0.04609477, 0.01682683, 0.01135751, ...,        nan,        nan,
#                nan]),
#  'eval_domain_loss_array': array([0.86828324, 0.43960234, 0.31507159, ...,        nan,        nan,
#                nan]),
#  'eval_loss_array': array([0.86828324, 0.43960234, 0.31507159, ...,        nan,        nan,
#                nan]),
#  'test_class_accuracy_array': array([], dtype=float64),
#  'test_class_precision_array': array([], dtype=float64),
#  'test_class_recall_array': array([], dtype=float64),
#  'test_class_f1_score_array': array([], dtype=float64),
#  'test_domain_accuracy_array': array([], dtype=float64),
#  'test_domain_precision_array': array([], dtype=float64),
# ...

# %%
plt.plot(loss_dict['train_class_loss_array'])

# %%
plt.plot(loss_dict['train_domain_loss_array'][10:])

# %%
plt.plot(loss_dict['eval_class_loss_array'][10:])

# %%
plt.plot(loss_dict['eval_domain_loss_array'][10:])

# %%
plt.plot(loss_dict['eval_loss_array'][10:])
